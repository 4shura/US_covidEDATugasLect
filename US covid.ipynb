# %%
#Load the required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#Load the data
df = pd.read_csv('C:/Users/user/Downloads/archive/US_counties_COVID19_health_weather_data.csv')


#View the data
df.head()
pd.set_option('display.max_rows', 500)

# %%
#Basic information

df.info()

#Describe the data

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 790331 entries, 0 to 790330
# Columns: 227 entries, date to date_stay_at_home_effective
# dtypes: float64(214), int64(1), object(12)
# memory usage: 1.3+ GB
#                cases         deaths            lat            lon  \
# count  790331.000000  773676.000000  772496.000000  772496.000000
# mean     1585.732008      48.811459      38.341593     -91.885428
# std      8371.736299     441.930899       5.205564      12.721928
# min         1.000000       0.000000      19.598724    -166.890423
# 25%        29.000000       0.000000      34.639800     -97.670223
# 50%       174.000000       3.000000      38.300537     -89.914116
# 75%       768.000000      17.000000      41.694366     -83.229643
# max    430713.000000   24323.000000      69.311848     -67.629217
#
#        total_population      area_sqmi  population_density_per_sqmi  \
# count      7.724960e+05  772496.000000                772496.000000
# mean       1.115774e+05    1095.838893                   240.894839
# std        3.809754e+05    3508.169264                   988.954283
# min        7.600000e+01       2.050706                     0.038490
# 25%        1.248300e+04     428.600463                    19.559249
# 50%        2.798900e+04     608.259345                    47.951330
# 75%        7.521600e+04     913.499979                   129.528153
# max        1.005716e+07  145492.910697                 28069.675983
#
#           num_deaths  years_of_potential_life_lost_rate  \
# count  715923.000000                      715923.000000
# mean     1425.017005                        8546.189117
# std      3794.898763                        2584.564367
# min        32.000000                        2730.603992
# 25%       235.000000                        6764.487596
# 50%       497.000000                        8286.797606
# 75%      1171.000000                       10052.385436
# max     84296.000000                       29138.378057
#
#        percent_fair_or_poor_health  ...  max_temp_10d_avg  max_temp_15d_avg  \
# count                772496.000000  ...     732814.000000     723293.000000
# mean                     17.952691  ...         76.848410         77.036569
# std                       4.715072  ...         13.354074         12.910035
# min                       8.120645  ...         -5.210000         -0.540000
# 25%                      14.360908  ...         68.620000         68.813333
# 50%                      17.260055  ...         79.160000         79.280000
# 75%                      20.924156  ...         87.010000         86.873333
# max                      40.990687  ...        119.700000        118.153333
#
#        min_temp_3d_avg  min_temp_5d_avg  min_temp_10d_avg  min_temp_15d_avg  \
# count    752602.000000    749289.000000     739482.000000     732840.000000
# mean         53.023391        53.119427         53.354062         53.520905
# std          14.617407        14.249595         13.671343         13.369534
# min         -35.666667       -34.200000        -28.170000        -22.986667
# 25%          42.333333        42.660000         43.410000         43.840000
# 50%          54.666667        54.680000         54.630000         54.673333
# 75%          65.000000        64.760000         64.470000         64.406667
# max          93.700000        93.300000         92.650000         90.826667
#
#        dewpoint_3d_avg  dewpoint_5d_avg  dewpoint_10d_avg  dewpoint_15d_avg
# count    699082.000000    695496.000000     685485.000000     678642.000000
# mean         51.288410        51.383494         51.601097         51.748440
# std          15.714614        15.302272         14.684258         14.384477
# min         -36.700000       -33.240000        -23.290000        -16.606667
# 25%          39.400000        39.760000         40.550000         40.740000
# 50%          53.400000        53.320000         53.160000         53.180000
# 75%          64.666667        64.300000         64.020000         63.940000
# max          82.366667        81.580000         80.680000         79.920000
#
# [8 rows x 215 columns]

# %%
#Find the duplicates

df.duplicated().sum()
# Out:
# 0

# %%
#Find null values

df.isnull().sum()
# Out:
# date                                                        0
# county                                                      0
# state                                                       0
# fips                                                      163
# cases                                                       0
# deaths                                                  16655
# stay_at_home_announced                                      0
# stay_at_home_effective                                      0
# lat                                                     17835
# lon                                                     17835
# total_population                                        17835
# area_sqmi                                               17835
# population_density_per_sqmi                             17835
# num_deaths                                              74408
# years_of_potential_life_lost_rate                       74408
# percent_fair_or_poor_health                             17835
# average_number_of_physically_unhealthy_days             17835
# average_number_of_mentally_unhealthy_days               17835
# percent_low_birthweight                                 35382
# percent_smokers                                         17835
# percent_adults_with_obesity                             17835
# food_environment_index                                  22449
# percent_physically_inactive                             17835
# percent_with_access_to_exercise_opportunities           18701
# percent_excessive_drinking                              17835
# num_alcohol_impaired_driving_deaths                     24107
# num_driving_deaths                                      24107
# percent_driving_deaths_with_alcohol_involvement         24107
# num_chlamydia_cases                                     45401
# chlamydia_rate                                          45401
# teen_birth_rate                                         45172
# num_uninsured                                           17835
# percent_uninsured                                       17835
# num_primary_care_physicians                             51561
# primary_care_physicians_rate                            51047
# num_dentists                                            38665
# dentist_rate                                            38665
# num_mental_health_providers                             67855
# mental_health_provider_rate                             67855
# preventable_hospitalization_rate                        25000
# percent_with_annual_mammogram                           20804
# percent_vaccinated                                      20649
# high_school_graduation_rate                             37113
# num_some_college                                        17835
# population                                              17835
# percent_some_college                                    17835
# num_unemployed_CHR                                      17835
# labor_force                                             17835
# percent_unemployed_CHR                                  17835
# percent_children_in_poverty                             17835
# eightieth_percentile_income                             18326
# twentieth_percentile_income                             18326
# income_ratio                                            18326
# num_single_parent_households_CHR                        17853
# num_households_CHR                                      17853
# percent_single_parent_households_CHR                    17853
# num_associations                                        17835
# social_association_rate                                 17835
# annual_average_violent_crimes                           61879
# violent_crime_rate                                      61879
# num_injury_deaths                                       33978
# injury_death_rate                                       33978
# average_daily_pm2_5                                     24632
# presence_of_water_violation                             28439
# percent_severe_housing_problems                         17835
# severe_housing_cost_burden                              17835
# overcrowding                                            17835
# inadequate_facilities                                   17835
# percent_drive_alone_to_work                             18090
# num_workers_who_drive_alone                             18090
# percent_long_commute_drives_alone                       18090
# life_expectancy                                         29083
# num_deaths_2                                            26804
# age_adjusted_death_rate                                 26804
# num_deaths_3                                           299236
# child_mortality_rate                                   299236
# num_deaths_4                                           462963
# infant_mortality_rate                                  462963
# percent_frequent_physical_distress                      17835
# percent_frequent_mental_distress                        17835
# percent_adults_with_diabetes                            17835
# num_hiv_cases                                          215528
# hiv_prevalence_rate                                    215528
# num_food_insecure                                       17835
# percent_food_insecure                                   17835
# num_limited_access                                      22449
# percent_limited_access_to_healthy_foods                 22449
# num_drug_overdose_deaths                               347038
# drug_overdose_mortality_rate                           347038
# num_motor_vehicle_deaths                               109543
# motor_vehicle_mortality_rate                           109543
# percent_insufficient_sleep                              17835
# num_uninsured_2                                         17835
# percent_uninsured_2                                     17835
# num_uninsured_3                                         17835
# percent_uninsured_3                                     17835
# other_primary_care_provider_rate                        22999
# percent_disconnected_youth                             435025
# average_grade_performance                              169680
# average_grade_performance_2                            178054
# median_household_income                                 17835
# percent_enrolled_in_free_or_reduced_lunch               48446
# segregation_index                                      260344
# segregation_index_2                                     87899
# homicide_rate                                          457337
# num_deaths_5                                           186307
# suicide_rate_age_adjusted                              186307
# num_firearm_fatalities                                 222459
# firearm_fatalities_rate                                222459
# juvenile_arrest_rate                                   257075
# average_traffic_volume_per_meter_of_major_roadways      17835
# num_homeowners                                          17835
# percent_homeowners                                      17835
# num_households_with_severe_cost_burden                  18130
# percent_severe_housing_cost_burden                      18130
# population_2                                            17835
# percent_less_than_18_years_of_age                       17835
# percent_65_and_over                                     17835
# num_black                                               17835
# percent_black                                           17835
# num_american_indian_alaska_native                       17835
# percent_american_indian_alaska_native                   17835
# num_asian                                               17835
# percent_asian                                           17835
# num_native_hawaiian_other_pacific_islander              17835
# percent_native_hawaiian_other_pacific_islander          17835
# num_hispanic                                            17835
# percent_hispanic                                        17835
# num_non_hispanic_white                                  17835
# percent_non_hispanic_white                              17835
# num_not_proficient_in_english                           17835
# percent_not_proficient_in_english                       17835
# percent_female                                          17835
# num_rural                                               18942
# percent_rural                                           18942
# num_housing_units                                       17835
# num_households_CDC                                      17835
# num_below_poverty                                       17835
# num_unemployed_CDC                                      17835
# per_capita_income                                       17835
# num_no_highschool_diploma                               17835
# num_age_65_and_older                                    17835
# num_age_17_and_younger                                  17835
# num_disabled                                            17835
# num_single_parent_households_CDC                        17835
# num_minorities                                          17835
# num_limited_english_abilities                           17835
# num_multi_unit_housing                                  17835
# num_mobile_homes                                        17835
# num_overcrowding                                        17835
# num_households_with_no_vehicle                          17835
# num_institutionalized_in_group_quarters                 17835
# percent_below_poverty                                   17835
# percent_unemployed_CDC                                  17835
# percent_no_highschool_diploma                           17835
# percent_age_65_and_older                                17835
# percent_age_17_and_younger                              17835
# percent_disabled                                        17835
# percent_single_parent_households_CDC                    17835
# percent_minorities                                      17835
# percent_limited_english_abilities                       17835
# percent_multi_unit_housing                              17835
# percent_mobile_homes                                    17835
# percent_overcrowding                                    17835
# percent_no_vehicle                                      17835
# percent_institutionalized_in_group_quarters             17835
# percentile_rank_below_poverty                           17835
# percentile_rank_unemployed                              17835
# percentile_rank_per_capita_income                       17835
# percentile_rank_no_highschool_diploma                   17835
# percentile_rank_socioeconomic_theme                     17835
# percentile_rank_age_65_and_older                        17835
# percentile_rank_age_17_and_younger                      17835
# percentile_rank_disabled                                17835
# percentile_rank_single_parent_households                17835
# percentile_rank_household_comp_disability_theme         17835
# percentile_rank_minorities                              17835
# percentile_rank_limited_english_abilities               17835
# percentile_rank_minority_status_and_language_theme      17835
# percentile_rank_multi_unit_housing                      17835
# percentile_rank_mobile_homes                            17835
# percentile_rank_overcrowding                            17835
# percentile_rank_no_vehicle                              17835
# percentile_rank_institutionalized_in_group_quarters     17835
# percentile_rank_housing_and_transportation              17835
# percentile_rank_social_vulnerability                    17835
# km_to_closest_station                                   17835
# CALL                                                    84360
# ELEV_M                                                  17835
# station_id                                              34239
# station_name                                            34239
# mean_temp                                               34244
# min_temp                                                34399
# max_temp                                                35222
# dewpoint                                                87536
# sea_level_pressure                                     387426
# station_pressure                                       134979
# visibility                                              98906
# wind_speed                                              69244
# max_wind_speed                                          72664
# wind_gust                                              333692
# precipitation                                          106830
# precip_flag                                            106830
# fog                                                     34239
# rain                                                    34239
# snow                                                    34239
# hail                                                    34239
# thunder                                                 34239
# tornado                                                 34239
# mean_temp_3d_avg                                        37386
# mean_temp_5d_avg                                        40528
# mean_temp_10d_avg                                       49950
# mean_temp_15d_avg                                       56238
# max_temp_3d_avg                                         39981
# max_temp_5d_avg                                         44651
# max_temp_10d_avg                                        57517
# max_temp_15d_avg                                        67038
# min_temp_3d_avg                                         37729
# min_temp_5d_avg                                         41042
# min_temp_10d_avg                                        50849
# min_temp_15d_avg                                        57491
# dewpoint_3d_avg                                         91249
# dewpoint_5d_avg                                         94835
# dewpoint_10d_avg                                       104846
# dewpoint_15d_avg                                       111689
# date_stay_at_home_announced                            151112
# date_stay_at_home_effective                            151112
# dtype: int64

# %%
#Datatypes

df.dtypes
# Out:
# date                                                    object
# county                                                  object
# state                                                   object
# fips                                                    object
# cases                                                    int64
# deaths                                                 float64
# stay_at_home_announced                                  object
# stay_at_home_effective                                  object
# lat                                                    float64
# lon                                                    float64
# total_population                                       float64
# area_sqmi                                              float64
# population_density_per_sqmi                            float64
# num_deaths                                             float64
# years_of_potential_life_lost_rate                      float64
# percent_fair_or_poor_health                            float64
# average_number_of_physically_unhealthy_days            float64
# average_number_of_mentally_unhealthy_days              float64
# percent_low_birthweight                                float64
# percent_smokers                                        float64
# percent_adults_with_obesity                            float64
# food_environment_index                                 float64
# percent_physically_inactive                            float64
# percent_with_access_to_exercise_opportunities          float64
# percent_excessive_drinking                             float64
# num_alcohol_impaired_driving_deaths                    float64
# num_driving_deaths                                     float64
# percent_driving_deaths_with_alcohol_involvement        float64
# num_chlamydia_cases                                    float64
# chlamydia_rate                                         float64
# teen_birth_rate                                        float64
# num_uninsured                                          float64
# percent_uninsured                                      float64
# num_primary_care_physicians                            float64
# primary_care_physicians_rate                           float64
# num_dentists                                           float64
# dentist_rate                                           float64
# num_mental_health_providers                            float64
# mental_health_provider_rate                            float64
# preventable_hospitalization_rate                       float64
# percent_with_annual_mammogram                          float64
# percent_vaccinated                                     float64
# high_school_graduation_rate                            float64
# num_some_college                                       float64
# population                                             float64
# percent_some_college                                   float64
# num_unemployed_CHR                                     float64
# labor_force                                            float64
# percent_unemployed_CHR                                 float64
# percent_children_in_poverty                            float64
# eightieth_percentile_income                            float64
# twentieth_percentile_income                            float64
# income_ratio                                           float64
# num_single_parent_households_CHR                       float64
# num_households_CHR                                     float64
# percent_single_parent_households_CHR                   float64
# num_associations                                       float64
# social_association_rate                                float64
# annual_average_violent_crimes                          float64
# violent_crime_rate                                     float64
# num_injury_deaths                                      float64
# injury_death_rate                                      float64
# average_daily_pm2_5                                    float64
# presence_of_water_violation                             object
# percent_severe_housing_problems                        float64
# severe_housing_cost_burden                             float64
# overcrowding                                           float64
# inadequate_facilities                                  float64
# percent_drive_alone_to_work                            float64
# num_workers_who_drive_alone                            float64
# percent_long_commute_drives_alone                      float64
# life_expectancy                                        float64
# num_deaths_2                                           float64
# age_adjusted_death_rate                                float64
# num_deaths_3                                           float64
# child_mortality_rate                                   float64
# num_deaths_4                                           float64
# infant_mortality_rate                                  float64
# percent_frequent_physical_distress                     float64
# percent_frequent_mental_distress                       float64
# percent_adults_with_diabetes                           float64
# num_hiv_cases                                          float64
# hiv_prevalence_rate                                    float64
# num_food_insecure                                      float64
# percent_food_insecure                                  float64
# num_limited_access                                     float64
# percent_limited_access_to_healthy_foods                float64
# num_drug_overdose_deaths                               float64
# drug_overdose_mortality_rate                           float64
# num_motor_vehicle_deaths                               float64
# motor_vehicle_mortality_rate                           float64
# percent_insufficient_sleep                             float64
# num_uninsured_2                                        float64
# percent_uninsured_2                                    float64
# num_uninsured_3                                        float64
# percent_uninsured_3                                    float64
# other_primary_care_provider_rate                       float64
# percent_disconnected_youth                             float64
# average_grade_performance                              float64
# average_grade_performance_2                            float64
# median_household_income                                float64
# percent_enrolled_in_free_or_reduced_lunch              float64
# segregation_index                                      float64
# segregation_index_2                                    float64
# homicide_rate                                          float64
# num_deaths_5                                           float64
# suicide_rate_age_adjusted                              float64
# num_firearm_fatalities                                 float64
# firearm_fatalities_rate                                float64
# juvenile_arrest_rate                                   float64
# average_traffic_volume_per_meter_of_major_roadways     float64
# num_homeowners                                         float64
# percent_homeowners                                     float64
# num_households_with_severe_cost_burden                 float64
# percent_severe_housing_cost_burden                     float64
# population_2                                           float64
# percent_less_than_18_years_of_age                      float64
# percent_65_and_over                                    float64
# num_black                                              float64
# percent_black                                          float64
# num_american_indian_alaska_native                      float64
# percent_american_indian_alaska_native                  float64
# num_asian                                              float64
# percent_asian                                          float64
# num_native_hawaiian_other_pacific_islander             float64
# percent_native_hawaiian_other_pacific_islander         float64
# num_hispanic                                           float64
# percent_hispanic                                       float64
# num_non_hispanic_white                                 float64
# percent_non_hispanic_white                             float64
# num_not_proficient_in_english                          float64
# percent_not_proficient_in_english                      float64
# percent_female                                         float64
# num_rural                                              float64
# percent_rural                                          float64
# num_housing_units                                      float64
# num_households_CDC                                     float64
# num_below_poverty                                      float64
# num_unemployed_CDC                                     float64
# per_capita_income                                      float64
# num_no_highschool_diploma                              float64
# num_age_65_and_older                                   float64
# num_age_17_and_younger                                 float64
# num_disabled                                           float64
# num_single_parent_households_CDC                       float64
# num_minorities                                         float64
# num_limited_english_abilities                          float64
# num_multi_unit_housing                                 float64
# num_mobile_homes                                       float64
# num_overcrowding                                       float64
# num_households_with_no_vehicle                         float64
# num_institutionalized_in_group_quarters                float64
# percent_below_poverty                                  float64
# percent_unemployed_CDC                                 float64
# percent_no_highschool_diploma                          float64
# percent_age_65_and_older                               float64
# percent_age_17_and_younger                             float64
# percent_disabled                                       float64
# percent_single_parent_households_CDC                   float64
# percent_minorities                                     float64
# percent_limited_english_abilities                      float64
# percent_multi_unit_housing                             float64
# percent_mobile_homes                                   float64
# percent_overcrowding                                   float64
# percent_no_vehicle                                     float64
# percent_institutionalized_in_group_quarters            float64
# percentile_rank_below_poverty                          float64
# percentile_rank_unemployed                             float64
# percentile_rank_per_capita_income                      float64
# percentile_rank_no_highschool_diploma                  float64
# percentile_rank_socioeconomic_theme                    float64
# percentile_rank_age_65_and_older                       float64
# percentile_rank_age_17_and_younger                     float64
# percentile_rank_disabled                               float64
# percentile_rank_single_parent_households               float64
# percentile_rank_household_comp_disability_theme        float64
# percentile_rank_minorities                             float64
# percentile_rank_limited_english_abilities              float64
# percentile_rank_minority_status_and_language_theme     float64
# percentile_rank_multi_unit_housing                     float64
# percentile_rank_mobile_homes                           float64
# percentile_rank_overcrowding                           float64
# percentile_rank_no_vehicle                             float64
# percentile_rank_institutionalized_in_group_quarters    float64
# percentile_rank_housing_and_transportation             float64
# percentile_rank_social_vulnerability                   float64
# km_to_closest_station                                  float64
# CALL                                                    object
# ELEV_M                                                 float64
# station_id                                             float64
# station_name                                            object
# mean_temp                                              float64
# min_temp                                               float64
# max_temp                                               float64
# dewpoint                                               float64
# sea_level_pressure                                     float64
# station_pressure                                       float64
# visibility                                             float64
# wind_speed                                             float64
# max_wind_speed                                         float64
# wind_gust                                              float64
# precipitation                                          float64
# precip_flag                                             object
# fog                                                    float64
# rain                                                   float64
# snow                                                   float64
# hail                                                   float64
# thunder                                                float64
# tornado                                                float64
# mean_temp_3d_avg                                       float64
# mean_temp_5d_avg                                       float64
# mean_temp_10d_avg                                      float64
# mean_temp_15d_avg                                      float64
# max_temp_3d_avg                                        float64
# max_temp_5d_avg                                        float64
# max_temp_10d_avg                                       float64
# max_temp_15d_avg                                       float64
# min_temp_3d_avg                                        float64
# min_temp_5d_avg                                        float64
# min_temp_10d_avg                                       float64
# min_temp_15d_avg                                       float64
# dewpoint_3d_avg                                        float64
# dewpoint_5d_avg                                        float64
# dewpoint_10d_avg                                       float64
# dewpoint_15d_avg                                       float64
# date_stay_at_home_announced                             object
# date_stay_at_home_effective                             object
# dtype: object

# %%
#Correlation 

df.corr()
# Out:
#                                                        cases    deaths  \
# cases                                               1.000000  0.779383
# deaths                                              0.779383  1.000000
# lat                                                -0.055813 -0.005333
# lon                                                 0.016699  0.057830
# total_population                                    0.745575  0.631016
# area_sqmi                                           0.020906  0.001189
# population_density_per_sqmi                         0.456909  0.594185
# num_deaths                                          0.729114  0.597325
# years_of_potential_life_lost_rate                  -0.118015 -0.080618
# percent_fair_or_poor_health                        -0.022943 -0.019993
# average_number_of_physically_unhealthy_days        -0.059259 -0.041858
# average_number_of_mentally_unhealthy_days          -0.055187 -0.034805
# percent_low_birthweight                             0.010493  0.011315
# percent_smokers                                    -0.112744 -0.077841
# percent_adults_with_obesity                        -0.138786 -0.104077
# food_environment_index                              0.058465  0.049165
# percent_physically_inactive                        -0.117443 -0.065177
# percent_with_access_to_exercise_opportunities       0.181097  0.121126
# percent_excessive_drinking                          0.067162  0.045822
# num_alcohol_impaired_driving_deaths                 0.590804  0.317225
# num_driving_deaths                                  0.652828  0.393586
# percent_driving_deaths_with_alcohol_involvement    -0.021457 -0.026969
# num_chlamydia_cases                                 0.743769  0.686291
# chlamydia_rate                                      0.103954  0.066463
# teen_birth_rate                                    -0.081501 -0.068786
# num_uninsured                                       0.702971  0.500800
# percent_uninsured                                  -0.015819 -0.036279
# num_primary_care_physicians                         0.716363  0.615722
# primary_care_physicians_rate                        0.114927  0.083324
# num_dentists                                        0.721675  0.626546
# dentist_rate                                        0.148148  0.112465
# num_mental_health_providers                         0.671915  0.613320
# mental_health_provider_rate                         0.090917  0.076411
# preventable_hospitalization_rate                   -0.020970 -0.011853
# percent_with_annual_mammogram                      -0.003773  0.002470
# percent_vaccinated                                  0.065349  0.043281
# high_school_graduation_rate                        -0.085427 -0.059434
# num_some_college                                    0.737558  0.644559
# population                                          0.746065  0.640009
# percent_some_college                                0.109008  0.076917
# num_unemployed_CHR                                  0.738849  0.613824
# labor_force                                         0.739684  0.613099
# percent_unemployed_CHR                             -0.015873 -0.002540
# percent_children_in_poverty                        -0.046411 -0.028346
# eightieth_percentile_income                         0.201473  0.160392
# twentieth_percentile_income                         0.095415  0.059734
# income_ratio                                        0.086715  0.099160
# num_single_parent_households_CHR                    0.750192  0.629969
# num_households_CHR                                  0.737807  0.596840
# percent_single_parent_households_CHR                0.029979  0.020840
# num_associations                                    0.703663  0.596007
# social_association_rate                            -0.099659 -0.060458
# annual_average_violent_crimes                       0.731049  0.644569
# violent_crime_rate                                  0.161652  0.101466
# num_injury_deaths                                   0.694056  0.530485
# injury_death_rate                                  -0.140560 -0.095984
# average_daily_pm2_5                                 0.104505  0.056373
# percent_severe_housing_problems                     0.218456  0.161474
# severe_housing_cost_burden                          0.234640  0.178152
# overcrowding                                        0.117785  0.076745
# inadequate_facilities                              -0.026204 -0.014979
# percent_drive_alone_to_work                        -0.126526 -0.172728
# num_workers_who_drive_alone                         0.740798  0.621027
# percent_long_commute_drives_alone                   0.089711  0.086098
# life_expectancy                                     0.117530  0.086815
# num_deaths_2                                        0.729632  0.597192
# age_adjusted_death_rate                            -0.111035 -0.077160
# num_deaths_3                                        0.709829  0.546105
# child_mortality_rate                               -0.105922 -0.080540
# num_deaths_4                                        0.705108  0.560697
# infant_mortality_rate                              -0.118924 -0.093258
# percent_frequent_physical_distress                 -0.049963 -0.038313
# percent_frequent_mental_distress                   -0.059904 -0.041689
# percent_adults_with_diabetes                       -0.089671 -0.054662
# num_hiv_cases                                       0.726427  0.808793
# hiv_prevalence_rate                                 0.248685  0.207523
# num_food_insecure                                   0.739829  0.643464
# percent_food_insecure                              -0.031414 -0.027829
# num_limited_access                                  0.479804  0.224912
# percent_limited_access_to_healthy_foods            -0.060404 -0.049555
# num_drug_overdose_deaths                            0.646034  0.583179
# drug_overdose_mortality_rate                       -0.037519  0.000193
# num_motor_vehicle_deaths                            0.675270  0.431584
# motor_vehicle_mortality_rate                       -0.165293 -0.117239
# percent_insufficient_sleep                          0.063044  0.063351
# num_uninsured_2                                     0.710681  0.513660
# percent_uninsured_2                                -0.007032 -0.031133
# num_uninsured_3                                     0.609999  0.379366
# percent_uninsured_3                                -0.054992 -0.055351
# other_primary_care_provider_rate                    0.050087  0.031985
# percent_disconnected_youth                         -0.097673 -0.063277
# average_grade_performance                           0.000675 -0.010409
# average_grade_performance_2                        -0.016094 -0.032358
# median_household_income                             0.151928  0.114190
# percent_enrolled_in_free_or_reduced_lunch           0.006164  0.007696
# segregation_index                                   0.096526  0.089598
# segregation_index_2                                 0.114795  0.097400
# homicide_rate                                      -0.008388 -0.013438
# num_deaths_5                                        0.665779  0.474286
# suicide_rate_age_adjusted                          -0.152297 -0.115157
# num_firearm_fatalities                              0.625419  0.385513
# firearm_fatalities_rate                            -0.122994 -0.103271
# juvenile_arrest_rate                               -0.068594 -0.058481
# average_traffic_volume_per_meter_of_major_roadways  0.433342  0.410441
# num_homeowners                                      0.700022  0.531069
# percent_homeowners                                 -0.213122 -0.151749
# num_households_with_severe_cost_burden              0.753766  0.704623
# percent_severe_housing_cost_burden                  0.231210  0.177058
# population_2                                        0.743692  0.621028
# percent_less_than_18_years_of_age                   0.032708 -0.004319
# percent_65_and_over                                -0.144263 -0.074647
# num_black                                           0.687406  0.680649
# percent_black                                       0.067438  0.048488
# num_american_indian_alaska_native                   0.588113  0.493980
# percent_american_indian_alaska_native              -0.022774 -0.014828
# num_asian                                           0.615325  0.583917
# percent_asian                                       0.267690  0.206804
# num_native_hawaiian_other_pacific_islander          0.310053  0.221784
# percent_native_hawaiian_other_pacific_islander      0.031434  0.008462
# num_hispanic                                        0.690370  0.512428
# percent_hispanic                                    0.160836  0.087346
# num_non_hispanic_white                              0.658050  0.543870
# percent_non_hispanic_white                         -0.189242 -0.118758
# num_not_proficient_in_english                       0.716921  0.631438
# percent_not_proficient_in_english                   0.249044  0.165502
# percent_female                                      0.075108  0.060600
# num_rural                                           0.119732  0.042615
# percent_rural                                      -0.250831 -0.158838
# num_housing_units                                   0.748043  0.648542
# num_households_CDC                                  0.745582  0.646976
# num_below_poverty                                   0.752828  0.670727
# num_unemployed_CDC                                  0.743596  0.644212
# per_capita_income                                   0.142701  0.118479
# num_no_highschool_diploma                           0.733539  0.639432
# num_age_65_and_older                                0.738372  0.638891
# num_age_17_and_younger                              0.738812  0.601672
# num_disabled                                        0.739725  0.633659
# num_single_parent_households_CDC                    0.753341  0.651604
# num_minorities                                      0.739091  0.632671
# num_limited_english_abilities                       0.712537  0.628177
# num_multi_unit_housing                              0.729282  0.817508
# num_mobile_homes                                    0.361295  0.157449
# num_overcrowding                                    0.679606  0.627139
# num_households_with_no_vehicle                      0.620836  0.879506
# num_institutionalized_in_group_quarters             0.684882  0.624346
# percent_below_poverty                              -0.016652 -0.009863
# percent_unemployed_CDC                              0.030549  0.028488
# percent_no_highschool_diploma                      -0.000821  0.001923
# percent_age_65_and_older                           -0.143693 -0.076792
# percent_age_17_and_younger                          0.044501  0.006340
# percent_disabled                                   -0.152934 -0.094272
# percent_single_parent_households_CDC                0.078302  0.044278
# percent_minorities                                  0.189114  0.123248
# percent_limited_english_abilities                   0.245970  0.168424
# percent_multi_unit_housing                          0.371251  0.292297
# percent_mobile_homes                               -0.143675 -0.099323
# percent_overcrowding                                0.123638  0.087215
# percent_no_vehicle                                  0.171841  0.248658
# percent_institutionalized_in_group_quarters        -0.042075 -0.027349
# percentile_rank_below_poverty                      -0.008230 -0.008071
# percentile_rank_unemployed                          0.049083  0.040886
# percentile_rank_per_capita_income                  -0.124280 -0.086310
# percentile_rank_no_highschool_diploma               0.004404  0.004184
# percentile_rank_socioeconomic_theme                -0.022636 -0.014590
# percentile_rank_age_65_and_older                   -0.163123 -0.091382
# percentile_rank_age_17_and_younger                  0.051949  0.010669
# percentile_rank_disabled                           -0.164686 -0.101515
# percentile_rank_single_parent_households            0.089014  0.043471
# percentile_rank_household_comp_disability_theme    -0.105428 -0.072274
# percentile_rank_minorities                          0.170323  0.108133
# percentile_rank_limited_english_abilities           0.191647  0.122868
# percentile_rank_minority_status_and_language_theme  0.197911  0.125964
# percentile_rank_multi_unit_housing                  0.214548  0.134660
# percentile_rank_mobile_homes                       -0.174981 -0.123365
# percentile_rank_overcrowding                        0.120176  0.071104
# percentile_rank_no_vehicle                          0.091655  0.089101
# percentile_rank_institutionalized_in_group_quar... -0.019891 -0.010468
# percentile_rank_housing_and_transportation          0.104123  0.071516
# percentile_rank_social_vulnerability                0.048257  0.029005
# km_to_closest_station                              -0.112031 -0.076067
# ELEV_M                                             -0.065672 -0.052866
# station_id                                         -0.018099 -0.009171
# mean_temp                                           0.018944  0.019210
# min_temp                                            0.024430  0.024059
# max_temp                                            0.008436  0.010381
# dewpoint                                           -0.002684  0.010272
# sea_level_pressure                                  0.035571  0.015725
# station_pressure                                   -0.078004 -0.110106
# visibility                                          0.000231  0.002950
# wind_speed                                         -0.006480 -0.008839
# max_wind_speed                                     -0.021714 -0.016039
# wind_gust                                          -0.003298 -0.006260
# precipitation                                       0.002400  0.001813
# fog                                                -0.004709 -0.002591
# rain                                               -0.007930  0.001082
# snow                                               -0.006837 -0.008873
# hail                                                0.000198  0.000425
# thunder                                            -0.004804 -0.000200
# tornado                                            -0.000026  0.000244
# mean_temp_3d_avg                                    0.021514  0.020258
# mean_temp_5d_avg                                    0.023943  0.021091
# mean_temp_10d_avg                                   0.029132  0.022533
# mean_temp_15d_avg                                   0.033789  0.023806
# max_temp_3d_avg                                     0.011077  0.011304
# max_temp_5d_avg                                     0.013472  0.012026
# max_temp_10d_avg                                    0.018957  0.013379
# max_temp_15d_avg                                    0.024208  0.014731
# min_temp_3d_avg                                     0.027078  0.025405
# min_temp_5d_avg                                     0.029540  0.026354
# min_temp_10d_avg                                    0.034751  0.027987
# min_temp_15d_avg                                    0.039270  0.029321
# dewpoint_3d_avg                                    -0.001068  0.011048
# dewpoint_5d_avg                                     0.000612  0.011661
# dewpoint_10d_avg                                    0.004066  0.012657
# dewpoint_15d_avg                                    0.007168  0.013515
#
#                                                          lat       lon  \
# cases                                              -0.055813  0.016699
# deaths                                             -0.005333  0.057830
# lat                                                 1.000000 -0.268441
# lon                                                -0.268441  1.000000
# total_population                                   -0.050302 -0.015284
# area_sqmi                                           0.248089 -0.369932
# population_density_per_sqmi                        -0.001543  0.122354
# num_deaths                                         -0.062652 -0.006293
# years_of_potential_life_lost_rate                  -0.300083  0.102087
# percent_fair_or_poor_health                        -0.542817  0.103708
# average_number_of_physically_unhealthy_days        -0.392889  0.128762
# average_number_of_mentally_unhealthy_days          -0.404688  0.250145
# percent_low_birthweight                            -0.503549  0.236569
# percent_smokers                                    -0.182124  0.253238
# percent_adults_with_obesity                        -0.127642  0.178220
# food_environment_index                              0.282510  0.135316
# percent_physically_inactive                        -0.358396  0.245150
# percent_with_access_to_exercise_opportunities       0.239192 -0.071690
# percent_excessive_drinking                          0.468549 -0.140860
# num_alcohol_impaired_driving_deaths                -0.119845 -0.052713
# num_driving_deaths                                 -0.147468 -0.031292
# percent_driving_deaths_with_alcohol_involvement     0.217189 -0.104900
# num_chlamydia_cases                                -0.049331 -0.025931
# chlamydia_rate                                     -0.195233 -0.031766
# teen_birth_rate                                    -0.410863 -0.063572
# num_uninsured                                      -0.120995 -0.024735
# percent_uninsured                                  -0.455630 -0.194821
# num_primary_care_physicians                        -0.026622 -0.015768
# primary_care_physicians_rate                        0.218799 -0.045623
# num_dentists                                       -0.025174 -0.028695
# dentist_rate                                        0.224906 -0.080787
# num_mental_health_providers                         0.007316 -0.053579
# mental_health_provider_rate                         0.212090 -0.165325
# preventable_hospitalization_rate                   -0.303363  0.287916
# percent_with_annual_mammogram                       0.326091  0.285189
# percent_vaccinated                                  0.081575  0.305545
# high_school_graduation_rate                        -0.027630  0.208351
# num_some_college                                   -0.037616 -0.023766
# population                                         -0.049627 -0.025957
# percent_some_college                                0.371354 -0.057988
# num_unemployed_CHR                                 -0.043364 -0.023087
# labor_force                                        -0.044712 -0.016486
# percent_unemployed_CHR                             -0.039545 -0.061963
# percent_children_in_poverty                        -0.443990  0.100439
# eightieth_percentile_income                         0.201163 -0.058392
# twentieth_percentile_income                         0.323957 -0.099690
# income_ratio                                       -0.345122  0.103208
# num_single_parent_households_CHR                   -0.069552 -0.011907
# num_households_CHR                                 -0.057421 -0.029240
# percent_single_parent_households_CHR               -0.325543  0.180642
# num_associations                                   -0.025538  0.041888
# social_association_rate                             0.159772  0.093982
# annual_average_violent_crimes                      -0.060942 -0.023928
# violent_crime_rate                                 -0.293525  0.005393
# num_injury_deaths                                  -0.058836 -0.001430
# injury_death_rate                                   0.019810 -0.117408
# average_daily_pm2_5                                -0.340893  0.425681
# percent_severe_housing_problems                    -0.076689 -0.183692
# severe_housing_cost_burden                         -0.147511  0.102029
# overcrowding                                       -0.042026 -0.405014
# inadequate_facilities                               0.226452 -0.322897
# percent_drive_alone_to_work                        -0.381736  0.415804
# num_workers_who_drive_alone                        -0.042714 -0.014049
# percent_long_commute_drives_alone                  -0.280650  0.346351
# life_expectancy                                     0.317490 -0.204305
# num_deaths_2                                       -0.071592  0.011060
# age_adjusted_death_rate                            -0.377252  0.155434
# num_deaths_3                                       -0.062091 -0.063315
# child_mortality_rate                               -0.182705 -0.024543
# num_deaths_4                                       -0.056686 -0.071396
# infant_mortality_rate                              -0.234657  0.171010
# percent_frequent_physical_distress                 -0.416689  0.119492
# percent_frequent_mental_distress                   -0.403724  0.200165
# percent_adults_with_diabetes                       -0.306950  0.252185
# num_hiv_cases                                      -0.043722  0.009048
# hiv_prevalence_rate                                -0.383427  0.195913
# num_food_insecure                                  -0.071602 -0.013669
# percent_food_insecure                              -0.412357  0.044657
# num_limited_access                                 -0.140319 -0.016486
# percent_limited_access_to_healthy_foods            -0.012959 -0.270359
# num_drug_overdose_deaths                           -0.014511  0.022741
# drug_overdose_mortality_rate                        0.057069  0.278716
# num_motor_vehicle_deaths                           -0.122467 -0.064131
# motor_vehicle_mortality_rate                       -0.294762 -0.103537
# percent_insufficient_sleep                         -0.412094  0.451394
# num_uninsured_2                                    -0.120048 -0.023352
# percent_uninsured_2                                -0.489805 -0.178839
# num_uninsured_3                                    -0.122266 -0.034251
# percent_uninsured_3                                -0.171219 -0.290899
# other_primary_care_provider_rate                    0.119561  0.042511
# percent_disconnected_youth                         -0.199419 -0.112241
# average_grade_performance                           0.258770  0.144895
# average_grade_performance_2                         0.212171  0.088489
# median_household_income                             0.270782 -0.069031
# percent_enrolled_in_free_or_reduced_lunch          -0.434554  0.080404
# segregation_index                                   0.402303 -0.122647
# segregation_index_2                                 0.083922  0.167130
# homicide_rate                                      -0.275463  0.032186
# num_deaths_5                                       -0.060533 -0.091702
# suicide_rate_age_adjusted                           0.153888 -0.350189
# num_firearm_fatalities                             -0.073143 -0.067183
# firearm_fatalities_rate                            -0.205150 -0.184470
# juvenile_arrest_rate                                0.021227  0.033092
# average_traffic_volume_per_meter_of_major_roadways  0.041096  0.011522
# num_homeowners                                     -0.047328  0.010099
# percent_homeowners                                  0.087690  0.117928
# num_households_with_severe_cost_burden             -0.042389 -0.013517
# percent_severe_housing_cost_burden                 -0.175382  0.093053
# population_2                                       -0.054008 -0.018415
# percent_less_than_18_years_of_age                  -0.032526 -0.242066
# percent_65_and_over                                 0.081833  0.035220
# num_black                                          -0.085839  0.086209
# percent_black                                      -0.439519  0.283876
# num_american_indian_alaska_native                  -0.013623 -0.176148
# percent_american_indian_alaska_native               0.228607 -0.305680
# num_asian                                          -0.028154 -0.087359
# percent_asian                                       0.023996 -0.192387
# num_native_hawaiian_other_pacific_islander         -0.075432 -0.217159
# percent_native_hawaiian_other_pacific_islander     -0.072648 -0.321371
# num_hispanic                                       -0.084348 -0.078605
# percent_hispanic                                   -0.300380 -0.318729
# num_non_hispanic_white                             -0.007197  0.033159
# percent_non_hispanic_white                          0.426675  0.168569
# num_not_proficient_in_english                      -0.058657 -0.050919
# percent_not_proficient_in_english                  -0.207869 -0.230627
# percent_female                                     -0.107959  0.229212
# num_rural                                          -0.037285  0.228110
# percent_rural                                       0.070377  0.004776
# num_housing_units                                  -0.049162  0.001776
# num_households_CDC                                 -0.043453 -0.003163
# num_below_poverty                                  -0.069345 -0.020935
# num_unemployed_CDC                                 -0.049384 -0.014528
# per_capita_income                                   0.327213 -0.039465
# num_no_highschool_diploma                          -0.071094 -0.029844
# num_age_65_and_older                               -0.056756  0.005599
# num_age_17_and_younger                             -0.055227 -0.027635
# num_disabled                                       -0.063332 -0.001849
# num_single_parent_households_CDC                   -0.055711 -0.003288
# num_minorities                                     -0.076332 -0.048154
# num_limited_english_abilities                      -0.056651 -0.052466
# num_multi_unit_housing                             -0.030319 -0.000043
# num_mobile_homes                                   -0.259810 -0.001371
# num_overcrowding                                   -0.047793 -0.070619
# num_households_with_no_vehicle                      0.001995  0.031081
# num_institutionalized_in_group_quarters            -0.038618  0.027677
# percent_below_poverty                              -0.375236  0.063424
# percent_unemployed_CDC                             -0.283594  0.097681
# percent_no_highschool_diploma                      -0.522236  0.080390
# percent_age_65_and_older                            0.064589  0.037298
# percent_age_17_and_younger                         -0.065864 -0.228873
# percent_disabled                                   -0.271180  0.103204
# percent_single_parent_households_CDC               -0.243632  0.055943
# percent_minorities                                 -0.430760 -0.159557
# percent_limited_english_abilities                  -0.217858 -0.228310
# percent_multi_unit_housing                          0.096048 -0.011187
# percent_mobile_homes                               -0.437078  0.073359
# percent_overcrowding                               -0.043158 -0.402551
# percent_no_vehicle                                  0.045207  0.051819
# percent_institutionalized_in_group_quarters        -0.056041  0.011915
# percentile_rank_below_poverty                      -0.404263  0.070707
# percentile_rank_unemployed                         -0.323942  0.142000
# percentile_rank_per_capita_income                  -0.374002  0.063045
# percentile_rank_no_highschool_diploma              -0.545639  0.115375
# percentile_rank_socioeconomic_theme                -0.479475  0.112925
# percentile_rank_age_65_and_older                    0.107659  0.037962
# percentile_rank_age_17_and_younger                 -0.117813 -0.202638
# percentile_rank_disabled                           -0.289334  0.110389
# percentile_rank_single_parent_households           -0.270683  0.082130
# percentile_rank_household_comp_disability_theme    -0.321305  0.004121
# percentile_rank_minorities                         -0.449620 -0.150405
# percentile_rank_limited_english_abilities          -0.230460 -0.172959
# percentile_rank_minority_status_and_language_theme -0.383702 -0.176999
# percentile_rank_multi_unit_housing                  0.225362 -0.022440
# percentile_rank_mobile_homes                       -0.420565  0.039455
# percentile_rank_overcrowding                       -0.253255 -0.302392
# percentile_rank_no_vehicle                         -0.101498  0.240111
# percentile_rank_institutionalized_in_group_quar...  0.038378  0.031143
# percentile_rank_housing_and_transportation         -0.211214 -0.011342
# percentile_rank_social_vulnerability               -0.492788  0.009367
# km_to_closest_station                               0.057016 -0.241095
# ELEV_M                                              0.183003 -0.434291
# station_id                                         -0.028981 -0.010503
# mean_temp                                          -0.433042  0.096522
# min_temp                                           -0.451056  0.169641
# max_temp                                           -0.403098  0.023730
# dewpoint                                           -0.406044  0.283173
# sea_level_pressure                                 -0.041989  0.120665
# station_pressure                                    0.363772 -0.119648
# visibility                                          0.018243 -0.061241
# wind_speed                                          0.150593 -0.209006
# max_wind_speed                                      0.124618 -0.208232
# wind_gust                                           0.125582 -0.171205
# precipitation                                      -0.046918  0.084123
# fog                                                -0.006865  0.085063
# rain                                               -0.007882  0.123267
# snow                                                0.145180 -0.044915
# hail                                                0.002378 -0.004183
# thunder                                            -0.088171  0.052989
# tornado                                            -0.002078  0.001437
# mean_temp_3d_avg                                   -0.448929  0.099356
# mean_temp_5d_avg                                   -0.460229  0.101338
# mean_temp_10d_avg                                  -0.478899  0.103560
# mean_temp_15d_avg                                  -0.489544  0.104235
# max_temp_3d_avg                                    -0.421934  0.024180
# max_temp_5d_avg                                    -0.434525  0.024238
# max_temp_10d_avg                                   -0.454760  0.023011
# max_temp_15d_avg                                   -0.466375  0.021495
# min_temp_3d_avg                                    -0.471093  0.176400
# min_temp_5d_avg                                    -0.483225  0.180294
# min_temp_10d_avg                                   -0.502561  0.185798
# min_temp_15d_avg                                   -0.513008  0.188313
# dewpoint_3d_avg                                    -0.422390  0.294492
# dewpoint_5d_avg                                    -0.433742  0.302403
# dewpoint_10d_avg                                   -0.450895  0.314511
# dewpoint_15d_avg                                   -0.459428  0.320485
#
#                                                     total_population  \
# cases                                                       0.745575
# deaths                                                      0.631016
# lat                                                        -0.050302
# lon                                                        -0.015284
# total_population                                            1.000000
# area_sqmi                                                   0.031378
# population_density_per_sqmi                                 0.524043
# num_deaths                                                  0.976867
# years_of_potential_life_lost_rate                          -0.185993
# percent_fair_or_poor_health                                -0.080382
# average_number_of_physically_unhealthy_days                -0.107428
# average_number_of_mentally_unhealthy_days                  -0.091090
# percent_low_birthweight                                    -0.012697
# percent_smokers                                            -0.184707
# percent_adults_with_obesity                                -0.215463
# food_environment_index                                      0.096765
# percent_physically_inactive                                -0.212115
# percent_with_access_to_exercise_opportunities               0.273197
# percent_excessive_drinking                                  0.121732
# num_alcohol_impaired_driving_deaths                         0.855833
# num_driving_deaths                                          0.900988
# percent_driving_deaths_with_alcohol_involvement            -0.014080
# num_chlamydia_cases                                         0.966576
# chlamydia_rate                                              0.127312
# teen_birth_rate                                            -0.149318
# num_uninsured                                               0.910942
# percent_uninsured                                          -0.070707
# num_primary_care_physicians                                 0.973309
# primary_care_physicians_rate                                0.184330
# num_dentists                                                0.983079
# dentist_rate                                                0.228531
# num_mental_health_providers                                 0.935677
# mental_health_provider_rate                                 0.159420
# preventable_hospitalization_rate                           -0.056686
# percent_with_annual_mammogram                               0.012145
# percent_vaccinated                                          0.119970
# high_school_graduation_rate                                -0.109841
# num_some_college                                            0.991478
# population                                                  0.996807
# percent_some_college                                        0.190227
# num_unemployed_CHR                                          0.988186
# labor_force                                                 0.997778
# percent_unemployed_CHR                                     -0.035839
# percent_children_in_poverty                                -0.104982
# eightieth_percentile_income                                 0.319205
# twentieth_percentile_income                                 0.178378
# income_ratio                                                0.087236
# num_single_parent_households_CHR                            0.981409
# num_households_CHR                                          0.994226
# percent_single_parent_households_CHR                        0.015452
# num_associations                                            0.959789
# social_association_rate                                    -0.138555
# annual_average_violent_crimes                               0.938360
# violent_crime_rate                                          0.200534
# num_injury_deaths                                           0.944830
# injury_death_rate                                          -0.197533
# average_daily_pm2_5                                         0.157131
# percent_severe_housing_problems                             0.285190
# severe_housing_cost_burden                                  0.312961
# overcrowding                                                0.144834
# inadequate_facilities                                      -0.037488
# percent_drive_alone_to_work                                -0.146504
# num_workers_who_drive_alone                                 0.998238
# percent_long_commute_drives_alone                           0.121599
# life_expectancy                                             0.178912
# num_deaths_2                                                0.976881
# age_adjusted_death_rate                                    -0.176323
# num_deaths_3                                                0.945948
# child_mortality_rate                                       -0.179321
# num_deaths_4                                                0.942551
# infant_mortality_rate                                      -0.196858
# percent_frequent_physical_distress                         -0.102175
# percent_frequent_mental_distress                           -0.108520
# percent_adults_with_diabetes                               -0.140562
# num_hiv_cases                                               0.853614
# hiv_prevalence_rate                                         0.285385
# num_food_insecure                                           0.977666
# percent_food_insecure                                      -0.057644
# num_limited_access                                          0.697321
# percent_limited_access_to_healthy_foods                    -0.094215
# num_drug_overdose_deaths                                    0.855492
# drug_overdose_mortality_rate                               -0.041609
# num_motor_vehicle_deaths                                    0.929216
# motor_vehicle_mortality_rate                               -0.259807
# percent_insufficient_sleep                                  0.068558
# num_uninsured_2                                             0.919720
# percent_uninsured_2                                        -0.060389
# num_uninsured_3                                             0.800975
# percent_uninsured_3                                        -0.105796
# other_primary_care_provider_rate                            0.067911
# percent_disconnected_youth                                 -0.172590
# average_grade_performance                                   0.034827
# average_grade_performance_2                                -0.006547
# median_household_income                                     0.258138
# percent_enrolled_in_free_or_reduced_lunch                  -0.029931
# segregation_index                                           0.134567
# segregation_index_2                                         0.149710
# homicide_rate                                              -0.049221
# num_deaths_5                                                0.938992
# suicide_rate_age_adjusted                                  -0.205776
# num_firearm_fatalities                                      0.864056
# firearm_fatalities_rate                                    -0.189441
# juvenile_arrest_rate                                       -0.100575
# average_traffic_volume_per_meter_of_major_roadways          0.560825
# num_homeowners                                              0.968182
# percent_homeowners                                         -0.283790
# num_households_with_severe_cost_burden                      0.979161
# percent_severe_housing_cost_burden                          0.305475
# population_2                                                0.999485
# percent_less_than_18_years_of_age                           0.023703
# percent_65_and_over                                        -0.196176
# num_black                                                   0.822352
# percent_black                                               0.063874
# num_american_indian_alaska_native                           0.791949
# percent_american_indian_alaska_native                      -0.039212
# num_asian                                                   0.877319
# percent_asian                                               0.443154
# num_native_hawaiian_other_pacific_islander                  0.500069
# percent_native_hawaiian_other_pacific_islander              0.079479
# num_hispanic                                                0.911187
# percent_hispanic                                            0.189263
# num_non_hispanic_white                                      0.919702
# percent_non_hispanic_white                                 -0.230122
# num_not_proficient_in_english                               0.913062
# percent_not_proficient_in_english                           0.296148
# percent_female                                              0.107981
# num_rural                                                   0.236418
# percent_rural                                              -0.365206
# num_housing_units                                           0.994773
# num_households_CDC                                          0.996866
# num_below_poverty                                           0.974426
# num_unemployed_CDC                                          0.986215
# per_capita_income                                           0.239588
# num_no_highschool_diploma                                   0.959654
# num_age_65_and_older                                        0.986093
# num_age_17_and_younger                                      0.995435
# num_disabled                                                0.988652
# num_single_parent_households_CDC                            0.986845
# num_minorities                                              0.967539
# num_limited_english_abilities                               0.911615
# num_multi_unit_housing                                      0.875998
# num_mobile_homes                                            0.542180
# num_overcrowding                                            0.903628
# num_households_with_no_vehicle                              0.680851
# num_institutionalized_in_group_quarters                     0.916098
# percent_below_poverty                                      -0.059484
# percent_unemployed_CDC                                      0.030532
# percent_no_highschool_diploma                              -0.048585
# percent_age_65_and_older                                   -0.197463
# percent_age_17_and_younger                                  0.041806
# percent_disabled                                           -0.221547
# percent_single_parent_households_CDC                        0.078846
# percent_minorities                                          0.228077
# percent_limited_english_abilities                           0.292986
# percent_multi_unit_housing                                  0.493522
# percent_mobile_homes                                       -0.218547
# percent_overcrowding                                        0.150373
# percent_no_vehicle                                          0.179408
# percent_institutionalized_in_group_quarters                -0.066116
# percentile_rank_below_poverty                              -0.049499
# percentile_rank_unemployed                                  0.057836
# percentile_rank_per_capita_income                          -0.214061
# percentile_rank_no_highschool_diploma                      -0.043207
# percentile_rank_socioeconomic_theme                        -0.072055
# percentile_rank_age_65_and_older                           -0.224546
# percentile_rank_age_17_and_younger                          0.052319
# percentile_rank_disabled                                   -0.237465
# percentile_rank_single_parent_households                    0.095940
# percentile_rank_household_comp_disability_theme            -0.174032
# percentile_rank_minorities                                  0.215951
# percentile_rank_limited_english_abilities                   0.258086
# percentile_rank_minority_status_and_language_theme          0.260063
# percentile_rank_multi_unit_housing                          0.318718
# percentile_rank_mobile_homes                               -0.262158
# percentile_rank_overcrowding                                0.138797
# percentile_rank_no_vehicle                                  0.110036
# percentile_rank_institutionalized_in_group_quar...         -0.027939
# percentile_rank_housing_and_transportation                  0.125310
# percentile_rank_social_vulnerability                        0.027801
# km_to_closest_station                                      -0.163073
# ELEV_M                                                     -0.087978
# station_id                                                 -0.021135
# mean_temp                                                   0.038193
# min_temp                                                    0.039568
# max_temp                                                    0.024396
# dewpoint                                                   -0.000731
# sea_level_pressure                                          0.006540
# station_pressure                                           -0.083213
# visibility                                                  0.004685
# wind_speed                                                 -0.001791
# max_wind_speed                                             -0.018022
# wind_gust                                                  -0.010903
# precipitation                                               0.005372
# fog                                                        -0.009637
# rain                                                        0.003673
# snow                                                       -0.011300
# hail                                                        0.005149
# thunder                                                     0.001287
# tornado                                                     0.001677
# mean_temp_3d_avg                                            0.039011
# mean_temp_5d_avg                                            0.039403
# mean_temp_10d_avg                                           0.039758
# mean_temp_15d_avg                                           0.039300
# max_temp_3d_avg                                             0.024916
# max_temp_5d_avg                                             0.025140
# max_temp_10d_avg                                            0.025363
# max_temp_15d_avg                                            0.024953
# min_temp_3d_avg                                             0.040887
# min_temp_5d_avg                                             0.041446
# min_temp_10d_avg                                            0.042080
# min_temp_15d_avg                                            0.041801
# dewpoint_3d_avg                                            -0.001186
# dewpoint_5d_avg                                            -0.001672
# dewpoint_10d_avg                                           -0.002895
# dewpoint_15d_avg                                           -0.004167
#
#                                                     area_sqmi  \
# cases                                                0.020906
# deaths                                               0.001189
# lat                                                  0.248089
# lon                                                 -0.369932
# total_population                                     0.031378
# area_sqmi                                            1.000000
# ...
# min_temp_3d_avg                                             0.894841
# min_temp_5d_avg                                             0.911723
# min_temp_10d_avg                                            0.928206
# min_temp_15d_avg                                            0.919152
# dewpoint_3d_avg                                             0.961745
# dewpoint_5d_avg                                             0.980966
# dewpoint_10d_avg                                            1.000000
# dewpoint_15d_avg                                            0.989621
#
#                                                     dewpoint_15d_avg
# cases                                                       0.007168
# deaths                                                      0.013515
# lat                                                        -0.459428
# lon                                                         0.320485
# total_population                                           -0.004167
# area_sqmi                                                  -0.171260
# population_density_per_sqmi                                 0.022648
# num_deaths                                                 -0.001096
# years_of_potential_life_lost_rate                           0.207144
# percent_fair_or_poor_health                                 0.303517
# average_number_of_physically_unhealthy_days                 0.233027
# average_number_of_mentally_unhealthy_days                   0.248497
# percent_low_birthweight                                     0.239123
# percent_smokers                                             0.232714
# percent_adults_with_obesity                                 0.221280
# food_environment_index                                     -0.127932
# percent_physically_inactive                                 0.311400
# percent_with_access_to_exercise_opportunities              -0.160913
# percent_excessive_drinking                                 -0.222504
# num_alcohol_impaired_driving_deaths                         0.013988
# num_driving_deaths                                          0.031604
# percent_driving_deaths_with_alcohol_involvement            -0.105354
# num_chlamydia_cases                                        -0.003122
# chlamydia_rate                                              0.131658
# teen_birth_rate                                             0.205452
# num_uninsured                                               0.033305
# percent_uninsured                                           0.173422
# num_primary_care_physicians                                -0.012807
# primary_care_physicians_rate                               -0.132917
# num_dentists                                               -0.016091
# dentist_rate                                               -0.133446
# num_mental_health_providers                                -0.036183
# mental_health_provider_rate                                -0.154217
# preventable_hospitalization_rate                            0.280192
# percent_with_annual_mammogram                              -0.029489
# percent_vaccinated                                          0.029962
# high_school_graduation_rate                                 0.067719
# num_some_college                                           -0.008672
# population                                                 -0.004420
# percent_some_college                                       -0.205883
# num_unemployed_CHR                                         -0.008931
# labor_force                                                -0.006720
# percent_unemployed_CHR                                      0.061755
# percent_children_in_poverty                                 0.249790
# eightieth_percentile_income                                -0.124212
# twentieth_percentile_income                                -0.193986
# income_ratio                                                0.200103
# num_single_parent_households_CHR                            0.006195
# num_households_CHR                                         -0.004452
# percent_single_parent_households_CHR                        0.228984
# num_associations                                            0.000664
# social_association_rate                                    -0.003601
# annual_average_violent_crimes                               0.004853
# violent_crime_rate                                          0.141221
# num_injury_deaths                                          -0.007018
# injury_death_rate                                          -0.052797
# average_daily_pm2_5                                         0.373993
# percent_severe_housing_problems                             0.017234
# severe_housing_cost_burden                                  0.067771
# overcrowding                                               -0.018488
# inadequate_facilities                                      -0.088702
# percent_drive_alone_to_work                                 0.276394
# num_workers_who_drive_alone                                -0.006591
# percent_long_commute_drives_alone                           0.220143
# life_expectancy                                            -0.260572
# num_deaths_2                                                0.008213
# age_adjusted_death_rate                                     0.257036
# num_deaths_3                                               -0.015661
# child_mortality_rate                                        0.164114
# num_deaths_4                                               -0.022649
# infant_mortality_rate                                       0.215293
# percent_frequent_physical_distress                          0.242792
# percent_frequent_mental_distress                            0.250186
# percent_adults_with_diabetes                                0.267327
# num_hiv_cases                                               0.012169
# hiv_prevalence_rate                                         0.263544
# num_food_insecure                                           0.010456
# percent_food_insecure                                       0.255971
# num_limited_access                                          0.032293
# percent_limited_access_to_healthy_foods                    -0.071413
# num_drug_overdose_deaths                                   -0.022798
# drug_overdose_mortality_rate                               -0.008677
# num_motor_vehicle_deaths                                    0.013190
# motor_vehicle_mortality_rate                                0.132191
# percent_insufficient_sleep                                  0.326661
# num_uninsured_2                                             0.033722
# percent_uninsured_2                                         0.197706
# num_uninsured_3                                             0.028662
# percent_uninsured_3                                        -0.003179
# other_primary_care_provider_rate                           -0.046361
# percent_disconnected_youth                                  0.118897
# average_grade_performance                                  -0.100138
# average_grade_performance_2                                -0.085128
# median_household_income                                    -0.164401
# percent_enrolled_in_free_or_reduced_lunch                   0.227638
# segregation_index                                          -0.275534
# segregation_index_2                                         0.008558
# homicide_rate                                               0.188493
# num_deaths_5                                               -0.028707
# suicide_rate_age_adjusted                                  -0.196891
# num_firearm_fatalities                                     -0.007443
# firearm_fatalities_rate                                     0.057055
# juvenile_arrest_rate                                        0.001887
# average_traffic_volume_per_meter_of_major_roadways         -0.033457
# num_homeowners                                             -0.003948
# percent_homeowners                                         -0.033922
# num_households_with_severe_cost_burden                     -0.003756
# percent_severe_housing_cost_burden                          0.082421
# population_2                                               -0.003065
# percent_less_than_18_years_of_age                          -0.014232
# percent_65_and_over                                        -0.051184
# num_black                                                   0.051087
# percent_black                                               0.326822
# num_american_indian_alaska_native                          -0.076657
# percent_american_indian_alaska_native                      -0.131964
# num_asian                                                  -0.012246
# percent_asian                                              -0.017130
# num_native_hawaiian_other_pacific_islander                 -0.007983
# percent_native_hawaiian_other_pacific_islander             -0.004016
# num_hispanic                                               -0.003169
# percent_hispanic                                           -0.052167
# num_non_hispanic_white                                     -0.018844
# percent_non_hispanic_white                                 -0.150989
# num_not_proficient_in_english                               0.001413
# percent_not_proficient_in_english                          -0.011139
# percent_female                                              0.110007
# num_rural                                                   0.047568
# percent_rural                                               0.008028
# num_housing_units                                          -0.002306
# num_households_CDC                                         -0.004596
# num_below_poverty                                           0.005124
# num_unemployed_CDC                                         -0.003983
# per_capita_income                                          -0.175563
# num_no_highschool_diploma                                   0.006279
# num_age_65_and_older                                        0.001633
# num_age_17_and_younger                                     -0.005403
# num_disabled                                                0.003874
# num_single_parent_households_CDC                            0.001571
# num_minorities                                              0.006215
# num_limited_english_abilities                              -0.000080
# num_multi_unit_housing                                      0.001609
# num_mobile_homes                                            0.091465
# num_overcrowding                                           -0.008077
# num_households_with_no_vehicle                             -0.004422
# num_institutionalized_in_group_quarters                    -0.003492
# percent_below_poverty                                       0.208932
# percent_unemployed_CDC                                      0.173705
# percent_no_highschool_diploma                               0.268378
# percent_age_65_and_older                                   -0.033007
# percent_age_17_and_younger                                 -0.008508
# percent_disabled                                            0.162785
# percent_single_parent_households_CDC                        0.184797
# percent_minorities                                          0.155209
# percent_limited_english_abilities                          -0.009774
# percent_multi_unit_housing                                 -0.066480
# percent_mobile_homes                                        0.208737
# percent_overcrowding                                       -0.017626
# percent_no_vehicle                                          0.087470
# percent_institutionalized_in_group_quarters                 0.049277
# percentile_rank_below_poverty                               0.220941
# percentile_rank_unemployed                                  0.200491
# percentile_rank_per_capita_income                           0.198670
# percentile_rank_no_highschool_diploma                       0.291630
# percentile_rank_socioeconomic_theme                         0.263883
# percentile_rank_age_65_and_older                           -0.038476
# percentile_rank_age_17_and_younger                          0.030654
# percentile_rank_disabled                                    0.174391
# percentile_rank_single_parent_households                    0.189872
# percentile_rank_household_comp_disability_theme             0.195075
# percentile_rank_minorities                                  0.158330
# percentile_rank_limited_english_abilities                   0.001775
# percentile_rank_minority_status_and_language_theme          0.093032
# percentile_rank_multi_unit_housing                         -0.113168
# percentile_rank_mobile_homes                                0.192721
# percentile_rank_overcrowding                                0.052424
# percentile_rank_no_vehicle                                  0.154676
# percentile_rank_institutionalized_in_group_quar...          0.014791
# percentile_rank_housing_and_transportation                  0.121705
# percentile_rank_social_vulnerability                        0.249420
# km_to_closest_station                                      -0.101439
# ELEV_M                                                     -0.494383
# station_id                                                  0.011478
# mean_temp                                                   0.788871
# min_temp                                                    0.838439
# max_temp                                                    0.684459
# dewpoint                                                    0.903421
# sea_level_pressure                                         -0.069681
# station_pressure                                           -0.246276
# visibility                                                 -0.016276
# wind_speed                                                 -0.302606
# max_wind_speed                                             -0.272136
# wind_gust                                                  -0.231339
# precipitation                                               0.085789
# fog                                                         0.061416
# rain                                                        0.099107
# snow                                                       -0.262727
# hail                                                       -0.005353
# thunder                                                     0.192114
# tornado                                                     0.005686
# mean_temp_3d_avg                                            0.814793
# mean_temp_5d_avg                                            0.831705
# mean_temp_10d_avg                                           0.856762
# mean_temp_15d_avg                                           0.866082
# max_temp_3d_avg                                             0.713500
# max_temp_5d_avg                                             0.732546
# max_temp_10d_avg                                            0.761204
# max_temp_15d_avg                                            0.773892
# min_temp_3d_avg                                             0.873619
# min_temp_5d_avg                                             0.892765
# min_temp_10d_avg                                            0.920385
# min_temp_15d_avg                                            0.929408
# dewpoint_3d_avg                                             0.936597
# dewpoint_5d_avg                                             0.958027
# dewpoint_10d_avg                                            0.989621
# dewpoint_15d_avg                                            1.000000
#
# [215 rows x 215 columns]

# %%
#Correlation plot

sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>
